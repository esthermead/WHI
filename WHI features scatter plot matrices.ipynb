# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas
from pandas.plotting import scatter_matrix

#read data
data = pandas.read_csv('ML-trimmed_features-WHI-trimmed.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'happinessScore', 'lifeLadder',
#        'logGDPperCapita', 'socialSupport', 'healthyLifeExpectancyAtBirth',
#        'freedomToMakeLifeChoices', 'generosity', 'perceptionsOfCorruption',
#        'positiveAffect', 'negativeAffect', 'GINIofHouseholdIncome'],
#       dtype='object')

# %%
#specify columns that show relation 1-WHI-retry2
scatter_matrix(data[['refugees', 'happinessScore']])
plt.show()

# %%
#specify columns that show relation 2-WHI-retry2
scatter_matrix(data[['refugees', 'lifeLadder']])
plt.show()

# %%
#specify columns that show relation 3-WHI-retry2
scatter_matrix(data[['refugees', 'logGDPperCapita']])
plt.show()

# %%
#specify columns that show relation 3-WHI-retry2
scatter_matrix(data[['refugees', 'socialSupport']])
plt.show()

# %%
#specify columns that show relation 4-WHI-retry2
scatter_matrix(data[['refugees', 'healthyLifeExpectancyAtBirth']])
plt.show()

# %%
#specify columns that show relation 5-WHI-retry2
scatter_matrix(data[['refugees', 'freedomToMakeLifeChoices']])
plt.show()

# %%
#specify columns that show relation 6-WHI-retry2
scatter_matrix(data[['refugees', 'generosity']])
plt.show()

# %%
#specify columns that show relation 7-WHI-retry2
scatter_matrix(data[['refugees', 'perceptionsOfCorruption']])
plt.show()

# %%
#specify columns that show relation 8-WHI-retry2
scatter_matrix(data[['refugees', 'positiveAffect']])
plt.show()

# %%
#specify columns that show relation 9-WHI-retry2
scatter_matrix(data[['refugees', 'negativeAffect']])
plt.show()

# %%
#specify columns that show relation 10-WHI-retry2
scatter_matrix(data[['refugees', 'GINIofHouseholdIncome']])
plt.show()
